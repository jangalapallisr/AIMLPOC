# %% [markdown]
# <a href="https://colab.research.google.com/github/jangalapallisr/AIMLPOC/blob/main/AAI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Welcome to Agentic AI world,..!")
# Out:
# Welcome to Agentic AI world,..!
